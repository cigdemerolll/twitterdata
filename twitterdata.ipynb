# %%
import json

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %%
tweets = []
for line in open('/Users/cigdemerol/Downloads/Total Merge userobjects_01.07.2021 - Ozgem (1).json', 'r'):
    try:
      tweets.append(json.loads(line))
    except Exception as e:
      pass

# %%
data = pd.DataFrame.from_dict(tweets, orient = "columns")

# %%
data
# Out:
#                         id               id_str                  name  \
# 0      1377260947631398913  1377260947631398913               Taha Öz
# 1                820100095            820100095           Ferda Çevik
# 2      1377257157888987141  1377257157888987141  cburakucar@gmail.com
# 3       906047018522599424   906047018522599424         Gökhan Taneri
# 4      1375898544897425415  1375898544897425415                 Musti
# ...                    ...                  ...                   ...
# 70107           2951609626           2951609626                Nurcan
# 70108  1397983447608610821  1397983447608610821        Devlet Mamedow
# 70109            169969756            169969756      EYT Halil YILMAZ
# 70110            633962167            633962167          Erhan Ozsuer
# 70111  1358537868646449155  1358537868646449155            محمد غيلان
#
#            screen_name           location       description   url  \
# ...

# %%
data.iloc[ 1, :]
# Out:
# id                                                                            820100095
# id_str                                                                        820100095
# name                                                                        Ferda Çevik
# screen_name                                                             ferdaismancevik
# location
# description
# url                                                                                None
# entities                                                  {'description': {'urls': []}}
# protected                                                                         False
# followers_count                                                                      34
# friends_count                                                                        91
# listed_count                                                                          0
# ...

# %%
data['account_rep'] = data['followers_count']/(data['friends_count'] + data['followers_count'])

# %%
data.loc[:,'account_rep']
# Out:
# 0        0.000000
# 1        0.272000
# 2        0.008000
# 3        0.045249
# 4        0.127273
#            ...
# 70107    0.069767
# 70108    0.000000
# 70109    0.139408
# 70110    0.008357
# 70111    0.072564
# Name: account_rep, Length: 70112, dtype: float64

# %%
high_rep = data['account_rep'] >= 0.5

# %%
data[high_rep]
# Out:
#                         id               id_str               name  \
# 15               472879716            472879716        Mehmet Aycı
# 16     1376830813984194561  1376830813984194561         Ghost Soul
# 19              2583636492           2583636492               uğur
# 34              2343662993           2343662993             şefika
# 45      962287316399206401   962287316399206401        Divan Kitap
# ...                    ...                  ...                ...
# 70041  1196830372429996032  1196830372429996032               İpek
# 70061           2488762285           2488762285    Bedirhan Keskin
# 70079            884497436            884497436  Bıla bıla bıla...
# 70086           1252681567           1252681567               Esin
# 70089            252022628            252022628         Özkan Kurt
#
#           screen_name              location  \
# 15         Mehmetayci  Ankara-Adana/Türkiye
# 16       soulpassion_       Ankara, Türkiye
# 19          ozklcugur
# ...

# %%
low_rep = data['account_rep'] <= 0.5

# %%
data[low_rep]
# Out:
#                         id               id_str                  name  \
# 0      1377260947631398913  1377260947631398913               Taha Öz
# 1                820100095            820100095           Ferda Çevik
# 2      1377257157888987141  1377257157888987141  cburakucar@gmail.com
# 3       906047018522599424   906047018522599424         Gökhan Taneri
# 4      1375898544897425415  1375898544897425415                 Musti
# ...                    ...                  ...                   ...
# 70107           2951609626           2951609626                Nurcan
# 70108  1397983447608610821  1397983447608610821        Devlet Mamedow
# 70109            169969756            169969756      EYT Halil YILMAZ
# 70110            633962167            633962167          Erhan Ozsuer
# 70111  1358537868646449155  1358537868646449155            محمد غيلان
#
#            screen_name           location       description   url  \
# ...

# %%
plt.hist(data['account_rep'], bins = 10)
plt.show()

# %%
twitter_egg = data.loc[data['default_profile_image'] == True]

# %%
twitter_egg
# Out:
#                         id               id_str                  name  \
# 2      1377257157888987141  1377257157888987141  cburakucar@gmail.com
# 3       906047018522599424   906047018522599424         Gökhan Taneri
# 8      1377259560377970689  1377259560377970689                Levent
# 11     1377259185142923272  1377259185142923272      kimbleontheloose
# 13     1314521244570714112  1314521244570714112                 betul
# ...                    ...                  ...                   ...
# 70073   906888230452301824   906888230452301824                Gülcan
# 70081           3535523057           3535523057          HATİCE PELİT
# 70097  1397627185628913669  1397627185628913669         rafetkalyon08
# 70104           2427763907           2427763907        ozlem gokdeniz
# 70110            633962167            633962167          Erhan Ozsuer
#
#            screen_name location description   url  \
# 2           cburakucar                       None
# ...

# %%
verified_accounts = data.loc[data['verified'] == True]

# %%
verified_accounts
# Out:
#                id      id_str                            name    screen_name  \
# 1059     66997818    66997818                  Nurettin Colak  NurettinColak
# 11100   156005263   156005263             Dr. Majid Rafizadeh   Dr_Rafizadeh
# 16099    56810175    56810175                           Rolli    rolliwrites
# 16643   231561698   231561698                Abdülkadir Özkan      akadir137
# 16690  1683467618  1683467618                    Levent Kemal    leventkemaI
# 24782    37927189    37927189                       DAAD News   DAAD_Germany
# 32378   404396098   404396098                     orhan aydın    orhanaydin6
# 41757    20571353    20571353                   Darcy Donavan   darcydonavan
# 48392    68806576    68806576                   Utku Demirsoy   utkudemirsoy
# 57538   160599963   160599963  Luke/Zonda - Staff @Trovo.Live        LTZONDA
# 66316  2704015396  2704015396                       Enez Özen   enezozenreal
# ...

# %%
botlike_behavior = data.loc[(data['friends_count'] == 2001) & (data['followers_count'] <=2000)]

# %%
botlike_behavior
# Out:
#                        id               id_str        name screen_name  \
# 9655  1331072465628368896  1331072465628368896  Sir Forhad  forhad_sir
#
#                 location            description   url  \
# 9655  Dhaka, Bangladesh.  I am an image of God.  None
#
#                            entities  protected  followers_count  ...  muting  \
# 9655  {'description': {'urls': []}}      False              232  ...   False
#
#       blocking blocked_by  translator_type  \
# 9655     False      False             none
#
#                                                  status profile_banner_url  \
# 9655  {'created_at': 'Sat Feb 27 11:14:19 +0000 2021...                NaN
#
#       withheld_in_countries  follow_requestage_url_https  is_translation_ted  \
# 9655                    NaN                          NaN                 NaN
#
#      account_rep
# 9655    0.103896
#
# [1 rows x 51 columns]

# %%
istanbullar = data.loc[data['location'] == 'istanbul']

# %%
istanbullar
# Out:
#                id      id_str              name      screen_name  location  \
# 158    1315417548  1315417548         kbbozkurt       kbbozkurt8  istanbul
# 1004    235130940   235130940         Cem Başar          Adjikac  istanbul
# 1337    143156330   143156330          tricarda         tricarda  istanbul
# 1482    123505857   123505857        Aysegul ER           agesul  istanbul
# 1783    104958189   104958189   yeşim hakimoğlu   YesimHakimoglu  istanbul
# ...           ...         ...               ...              ...       ...
# 69392    59144449    59144449  Alisan Cirakoglu  alisancirakoglu  istanbul
# 69546  2968702559  2968702559     sultan ekinci      sultifrutti  istanbul
# 69615   396084112   396084112               E B          ebaygin  istanbul
# 69695    66972886    66972886     Bülent Yılmaz    BulentYilmaz_  istanbul
# 70002   180282650   180282650       Ahmet Başak       ahmetbasak  istanbul
#
#                                              description  \
# 158
# ...

# %%
web_app = data.loc[data['status'] == '>Twitter Web App</a>']

# %%
web_app
# Out:
# Empty DataFrame
# Columns: [id, id_str, name, screen_name, location, description, url, entities, protected, followers_count, friends_count, listed_count, created_at, favourites_count, utc_offset, time_zone, geo_enabled, verified, statuses_count, lang, contributors_enabled, is_translator, is_translation_enabled, profile_background_color, profile_background_image_url, profile_background_image_url_https, profile_background_tile, profile_image_url, profile_image_url_https, profile_link_color, profile_sidebar_border_color, profile_sidebar_fill_color, profile_text_color, profile_use_background_image, has_extended_profile, default_profile, default_profile_image, following, live_following, follow_request_sent, notifications, muting, blocking, blocked_by, translator_type, status, profile_banner_url, withheld_in_countries, follow_requestage_url_https, is_translation_ted, account_rep]
# Index: []
#
# [0 rows x 51 columns]
